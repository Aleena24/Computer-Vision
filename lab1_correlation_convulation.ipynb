# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleena24/CV_lab/blob/main/lab1_correlation_convulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # filter2D & convolve function

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image_path = '/content/drive/MyDrive/research_dataset/BSD100/219090.png'
img = cv2.imread(image_path)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=481x321>

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

kernel = np.array([[0, -1, 0],
                   [-1, 5, -1],
                   [0, -1, 0]])

# %%
filtered_img = cv2.filter2D(gray_img, -1, kernel)
convolved_img = cv2.filter2D(gray_img, -1, np.flip(kernel))

# %%
cv2_imshow(gray_img)
cv2_imshow(filtered_img)
cv2_imshow(convolved_img)
# Out:
# <PIL.Image.Image image mode=L size=481x321>
# <PIL.Image.Image image mode=L size=481x321>
# <PIL.Image.Image image mode=L size=481x321>

# %% [markdown]
# # Kernels

# %% [markdown]
# # Identity kernel

# %%
# Convert the image to grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Define the identity kernel
identity_kernel = np.array([[0, 0, 0],
                             [0, 1, 0],
                             [0, 0, 0]])

# identity kernel using filter2D
identity_filtered_img = cv2.filter2D(gray_img, -1, identity_kernel)

cv2_imshow(gray_img)
cv2_imshow(identity_filtered_img)
# Out:
# <PIL.Image.Image image mode=L size=481x321>
# <PIL.Image.Image image mode=L size=481x321>

# %% [markdown]
# # Edge detection kernel

# %%
# Define the edge detection kernel
kernel = np.array([[-1, -1, -1],
                   [-1, 8, -1],
                   [-1, -1, -1]])

# filter using cv2.filter2D
edge_detected_img = cv2.filter2D(img, -1, kernel)

cv2_imshow(gray_img)
cv2_imshow(edge_detected_img)
# Out:
# <PIL.Image.Image image mode=L size=481x321>
# <PIL.Image.Image image mode=RGB size=481x321>

# %% [markdown]
# # Sharpen Kernel

# %%
# Define a sharpening kernel
sharpen_kernel = np.array([[0, -1, 0],
                           [-1, 5, -1],
                           [0, -1, 0]])

#sharpening kernel to the image
sharpened_img = cv2.filter2D(img, -1, sharpen_kernel)

cv2_imshow(gray_img)
cv2_imshow(sharpened_img)
# Out:
# <PIL.Image.Image image mode=L size=481x321>
# <PIL.Image.Image image mode=RGB size=481x321>

# %% [markdown]
# #Box Blur Kernel

# %%
# Define the box blur kernel
kernel_size = 5
box_blur_kernel = np.ones((kernel_size, kernel_size), dtype=np.float32) / (kernel_size * kernel_size)

#box blur kernel using cv2.filter2D
blurred_img = cv2.filter2D(img, -1, box_blur_kernel)

cv2_imshow(gray_img)
cv2_imshow(blurred_img)
# Out:
# <PIL.Image.Image image mode=L size=481x321>
# <PIL.Image.Image image mode=RGB size=481x321>

# %% [markdown]
# # Gaussian Blur Kernel

# %%
#Gaussian blur with a kernel size of (5, 5) and sigmaX value of 0
gau_blurred_img = cv2.GaussianBlur(img, (5, 5), 0)

cv2_imshow(gray_img)
cv2_imshow(gau_blurred_img)
# Out:
# <PIL.Image.Image image mode=L size=481x321>
# <PIL.Image.Image image mode=RGB size=481x321>

# %% [markdown]
# #Convolve function in SCIPY library

# %% [markdown]
# # ‘reflect’, ‘constant’, ‘nearest’, ‘mirror’, ‘wrap'#

# %%
import numpy as np
from scipy.ndimage import convolve
from scipy import misc
import matplotlib.pyplot as plt

# %%
gray_image = np.mean(img, axis=2)

kernel = np.array([[1, 1, 1],
                   [0, 0, 0],
                   [-1, -1, -1]])

#convolution operation with different modes
modes = ['reflect', 'constant', 'nearest', 'mirror', 'wrap']
for mode in modes:

    # convolution using the specified mode
    convolved_image = convolve(gray_image, kernel, mode=mode)

    # Display the convolved image for each mode
    plt.figure(figsize=(5, 5))
    plt.imshow(convolved_image, cmap='gray')
    plt.title(f"Convolved Image (Mode: {mode})")
    plt.axis('off')
    plt.show()
