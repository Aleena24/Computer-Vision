# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleena24/CV_lab/blob/main/extra3_sampling_and_quantization_techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np

# %%
# Load the continuous image
image = cv2.imread("/content/drive/MyDrive/research_dataset/BSD100/299086.png", cv2.IMREAD_GRAYSCALE)

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=481x321>

# %% [markdown]
# # Sampling
#
# Sampling in computer vision refers to the process of converting a continuous image into a discrete grid of pixels. Each pixel represents a sample of the continuous image at a specific location. The sampling rate determines how frequently samples are taken from the continuous image, which in turn affects the resolution of the resulting digital image.

# %%
# Perform sampling by selecting pixels at regular intervals
sampled_image = image[::2, ::2]

# Display the sampled image
cv2_imshow(sampled_image)
# Out:
# <PIL.Image.Image image mode=L size=241x161>

# %% [markdown]
# # Sampling Techniques

# %% [markdown]
# # Bi-linear interpolation
#
# Bi-linear interpolation estimates new pixel values by averaging the nearest four pixels

# %%
bilinear_image = cv2.resize(image, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_LINEAR)
cv2_imshow(bilinear_image)
# Out:
# <PIL.Image.Image image mode=L size=240x160>

# %% [markdown]
# # Bi-cubic interpolation
# bi-cubic interpolation uses a weighted average of 16 nearest pixels

# %%
# Bi-cubic interpolation
bicubic_image = cv2.resize(image, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_CUBIC)
cv2_imshow(bicubic_image)
# Out:
# <PIL.Image.Image image mode=L size=240x160>

# %% [markdown]
# # Nearest neighbor interpolation
# nearest neighbor interpolation assigns the value of the nearest pixel

# %%
nearest_neighbor_image = cv2.resize(image, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_NEAREST)
cv2_imshow(bilinear_image)
# Out:
# <PIL.Image.Image image mode=L size=240x160>

# %% [markdown]
# # Lanczos interpolation
# Lanczos interpolation applies a sinc function windowed by a Lanczos kernel to estimate pixel values.

# %%
lanczos_image = cv2.resize(image, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_LANCZOS4)
cv2_imshow(lanczos_image)
# Out:
# <PIL.Image.Image image mode=L size=240x160>

# %% [markdown]
# # Quantization
#
# Quantization in computer vision involves reducing the number of distinct intensity levels (or colors) used to represent an image. This process is essential for reducing the amount of data required to store or transmit an image while minimizing the perceptual loss of image quality.

# %%
# Perform quantization by reducing the number of intensity levels to 4 bits (16 levels)
quantized_image = np.uint8(image // 16 * 16)

# Display the quantized image
cv2_imshow(quantized_image)
# Out:
# <PIL.Image.Image image mode=L size=481x321>
