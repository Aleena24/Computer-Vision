# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleena24/CV_lab/blob/main/extra1_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # CV2

# %%
import os
import cv2

# %%
image_path = '/content/drive/MyDrive/research_dataset/BSD100'

# %%
def load_images(image_dir, image_size):
    images = []
    for filename in os.listdir(image_dir):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            img = cv2.imread(os.path.join(image_dir, filename))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            img = cv2.resize(img, (image_size, image_size))  # Resize to desired size
            images.append(img)
    return images

# %%
image_size = 256

# %%
images = load_images(image_path,  image_size)

# %% [markdown]
# #Matplotlib

# %%
import matplotlib.pyplot as plt
plt.imshow(images[0])
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # ImageIO

# %%
import imageio

# %%
def read_image(image_path):
  image = imageio.imread(image_path)
  return image

# %%
def save_image(image, output_path, format):
  imageio.imwrite(output_path, image, format=format)

# %%
image_path = '/content/drive/MyDrive/research_dataset/BSD100/76053.png'
image = read_image(image_path)
# Out:
# <ipython-input-9-dcbe1115fce4>:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(image_path)

# %% [markdown]
# conversion of file format from png to jpg

# %%
output_path = '/content/drive/MyDrive/research_dataset/BSD100/76053.jpg'
save_image(image, output_path, format= 'jpg')

# %%
plt.imshow(image)
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # PIL

# %%
from PIL import Image

# %%
image_path = '/content/drive/MyDrive/research_dataset/BSD100/167083.png'
img = Image.open(image_path)

# %% [markdown]
# conversion of file format from png to jpg

# %%
output_path = '/content/drive/MyDrive/research_dataset/BSD100/167083.jpg'

# %%
img.save(output_path, format='JPEG')

# %%
plt.imshow(img)
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
